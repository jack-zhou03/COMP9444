# %% [markdown]
# Base Model 1:

# %% [markdown]
# Base Model 2: Style GAN

# %% [markdown]
# Base Model 3: Denoising Diffusion Probabilistic Model (DDPM)

# %% [markdown]
# Base Model 4: Latent Diffusion Model (LDM)
